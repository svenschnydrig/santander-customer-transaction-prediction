# %%
## Importing libraries

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import warnings
warnings.filterwarnings('ignore')

SEED = 42
# Out:
# Mounted at /content/drive

# %%
##### The following codes were inspired by the following kernels:
######### 1/ Raghuram Nandepu ("https://medium.com/analytics-vidhya/santander-customer-transaction-prediction-an-end-to-end-machine-learning-project-2cb763172f8a") - primarily the part on oversampling and generation of the model

# %% [markdown]
# ## FE1

# %%
## Importing data

df_train = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/data/fe1-binary/train_fe1_binary.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/data/fe1-binary/test_fe1_binary.csv")

# %%
## Oversampling 

def oversampling(x, y, t=2):
    
    xs, xn = [], []
    
    for i in range(t // 2):
        mask = y == 0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        featnum = x1.shape[1] // 200 - 1

        for c in range(200):
            np.random.shuffle(ids)
            x1[:, [c] + [200 + featnum * c + idc for idc in range(featnum)]] = x1[ids][:, [c] + [200 + featnum * c + idc for idc in range(featnum)]]
        xn.append(x1)
    
    for i in range(t):
        mask = y > 0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        featnum = x1.shape[1] // 200 - 1
        
        for c in range(200):
            np.random.shuffle(ids)
            x1[:, [c] + [200 + featnum * c + idc for idc in range(1)]] = x1[ids][:, [c] + [200 + featnum * c + idc for idc in range(1)]]
        xs.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x, xs, xn])
    y = np.concatenate([y, ys, yn])
    
    return x, y

# %%
gbdt_param1 = {
    # Core Parameters
    'objective': 'binary',
    'boosting': 'gbdt',
    'learning_rate': 0.01,
    'num_leaves': 15,
    'tree_learner': 'serial',
    'num_threads': 8,
    'seed': SEED,
    
    # Learning Control Parameters
    'max_depth': -1,
    'min_data_in_leaf': 50,
    'min_sum_hessian_in_leaf': 10,  
    'bagging_fraction': 0.6,
    'bagging_freq': 5,
    'feature_fraction': 0.05,
    'lambda_l1': 1.,
    'bagging_seed': SEED,
    
    # Others
    'verbosity ': 1,
    'boost_from_average': False,
    'metric': 'auc',
}

# %%
predictors = df_train.columns.tolist()[2:]
X_test = df_test[predictors]

n_splits = 5
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

predictions = df_test[['ID_code']]

# %%
for fold, (train_ind, val_ind) in enumerate(skf.split(df_train, df_train.target.values)):
    
    X_train, y_train = df_train.iloc[train_ind][predictors], df_train.iloc[train_ind]['target']
    X_valid, y_valid = df_train.iloc[val_ind][predictors], df_train.iloc[val_ind]['target']

    N = 1
    p_valid, yp = 0, 0
        
    for i in range(N):
        print('\nFold {} - N {}'.format(fold + 1, i + 1))
        
        X_t, y_t = oversampling(X_train.values, y_train.values)
        weights = np.array([0.8] * X_t.shape[0])
        weights[:X_train.shape[0]] = 1.0
        print('Shape of X_train after augment: {}\nShape of y_train after augment: {}'.format(X_t.shape, y_t.shape))
        
        X_t = pd.DataFrame(X_t)
        X_t = X_t.add_prefix('var_')
    
        trn_data = lgb.Dataset(X_t, label=y_t, weight=weights)
        val_data = lgb.Dataset(X_valid, label=y_valid)
        evals_result = {}
        
        lgb_clf = lgb.train(gbdt_param1, trn_data, 100000, valid_sets=[trn_data, val_data], early_stopping_rounds=5000, verbose_eval=1000, evals_result=evals_result)
        p_valid += lgb_clf.predict(X_valid)
        yp += lgb_clf.predict(X_test)
        

    predictions['fold{}'.format(fold + 1)] = yp / N
# Out:
# Fold 1 - N 1
# Shape of X_train after augment: (336079, 400)
# Shape of y_train after augment: (336079,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896064	valid_1's auc: 0.883654
# [2000]	training's auc: 0.904787	valid_1's auc: 0.891197
# [3000]	training's auc: 0.911712	valid_1's auc: 0.896024
# [4000]	training's auc: 0.917136	valid_1's auc: 0.899608
# [5000]	training's auc: 0.921211	valid_1's auc: 0.901735
# [6000]	training's auc: 0.924518	valid_1's auc: 0.903123
# [7000]	training's auc: 0.927518	valid_1's auc: 0.904128
# [8000]	training's auc: 0.930292	valid_1's auc: 0.904702
# [9000]	training's auc: 0.932841	valid_1's auc: 0.905058
# [10000]	training's auc: 0.935287	valid_1's auc: 0.9053
# [11000]	training's auc: 0.937657	valid_1's auc: 0.905523
# [12000]	training's auc: 0.939857	valid_1's auc: 0.905667
# [13000]	training's auc: 0.942054	valid_1's auc: 0.905745
# [14000]	training's auc: 0.944205	valid_1's auc: 0.905857
# [15000]	training's auc: 0.946231	valid_1's auc: 0.9059
# [16000]	training's auc: 0.948206	valid_1's auc: 0.905913
# [17000]	training's auc: 0.950189	valid_1's auc: 0.905881
# [18000]	training's auc: 0.952075	valid_1's auc: 0.90584
# [19000]	training's auc: 0.9539	valid_1's auc: 0.905819
# [20000]	training's auc: 0.955679	valid_1's auc: 0.905854
# [21000]	training's auc: 0.957392	valid_1's auc: 0.905928
# Early stopping, best iteration is:
# [16326]	training's auc: 0.948875	valid_1's auc: 0.905956
#
# Fold 2 - N 1
# Shape of X_train after augment: (336079, 400)
# Shape of y_train after augment: (336079,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896686	valid_1's auc: 0.886497
# [2000]	training's auc: 0.905412	valid_1's auc: 0.893349
# [3000]	training's auc: 0.911517	valid_1's auc: 0.89734
# [4000]	training's auc: 0.916494	valid_1's auc: 0.900122
# [5000]	training's auc: 0.920516	valid_1's auc: 0.901974
# [6000]	training's auc: 0.92392	valid_1's auc: 0.903327
# [7000]	training's auc: 0.926817	valid_1's auc: 0.90417
# [8000]	training's auc: 0.929557	valid_1's auc: 0.904713
# [9000]	training's auc: 0.932104	valid_1's auc: 0.905166
# [10000]	training's auc: 0.934618	valid_1's auc: 0.905478
# [11000]	training's auc: 0.936942	valid_1's auc: 0.905638
# [12000]	training's auc: 0.939259	valid_1's auc: 0.905742
# [13000]	training's auc: 0.941459	valid_1's auc: 0.905804
# [14000]	training's auc: 0.943581	valid_1's auc: 0.905848
# [15000]	training's auc: 0.945642	valid_1's auc: 0.905831
# [16000]	training's auc: 0.947638	valid_1's auc: 0.905781
# [17000]	training's auc: 0.949562	valid_1's auc: 0.905742
# [18000]	training's auc: 0.951457	valid_1's auc: 0.905767
# Early stopping, best iteration is:
# [13665]	training's auc: 0.942876	valid_1's auc: 0.905891
#
# Fold 3 - N 1
# Shape of X_train after augment: (336078, 400)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.897088	valid_1's auc: 0.878497
# [2000]	training's auc: 0.905773	valid_1's auc: 0.885725
# [3000]	training's auc: 0.911781	valid_1's auc: 0.890152
# [4000]	training's auc: 0.916808	valid_1's auc: 0.893657
# [5000]	training's auc: 0.92077	valid_1's auc: 0.895882
# [6000]	training's auc: 0.924171	valid_1's auc: 0.897603
# [7000]	training's auc: 0.92713	valid_1's auc: 0.898749
# [8000]	training's auc: 0.929913	valid_1's auc: 0.899569
# [9000]	training's auc: 0.932429	valid_1's auc: 0.900154
# [10000]	training's auc: 0.934902	valid_1's auc: 0.90065
# [11000]	training's auc: 0.93724	valid_1's auc: 0.900908
# [12000]	training's auc: 0.939498	valid_1's auc: 0.901102
# [13000]	training's auc: 0.941669	valid_1's auc: 0.901206
# [14000]	training's auc: 0.943754	valid_1's auc: 0.901201
# [15000]	training's auc: 0.94577	valid_1's auc: 0.901191
# [16000]	training's auc: 0.947757	valid_1's auc: 0.901229
# [17000]	training's auc: 0.949701	valid_1's auc: 0.90124
# [18000]	training's auc: 0.951556	valid_1's auc: 0.901309
# [19000]	training's auc: 0.953375	valid_1's auc: 0.901296
# [20000]	training's auc: 0.955155	valid_1's auc: 0.901288
# [21000]	training's auc: 0.956867	valid_1's auc: 0.901278
# [22000]	training's auc: 0.958527	valid_1's auc: 0.901266
# [23000]	training's auc: 0.960135	valid_1's auc: 0.901212
# Early stopping, best iteration is:
# [18261]	training's auc: 0.952042	valid_1's auc: 0.901339
#
# Fold 4 - N 1
# Shape of X_train after augment: (336078, 400)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896631	valid_1's auc: 0.886817
# [2000]	training's auc: 0.905146	valid_1's auc: 0.892826
# [3000]	training's auc: 0.911313	valid_1's auc: 0.896696
# [4000]	training's auc: 0.916364	valid_1's auc: 0.899723
# [5000]	training's auc: 0.920335	valid_1's auc: 0.901683
# [6000]	training's auc: 0.923762	valid_1's auc: 0.903128
# [7000]	training's auc: 0.926713	valid_1's auc: 0.90394
# [8000]	training's auc: 0.929471	valid_1's auc: 0.904523
# [9000]	training's auc: 0.931958	valid_1's auc: 0.904858
# [10000]	training's auc: 0.934422	valid_1's auc: 0.905164
# [11000]	training's auc: 0.936739	valid_1's auc: 0.905328
# [12000]	training's auc: 0.93892	valid_1's auc: 0.905465
# [13000]	training's auc: 0.941079	valid_1's auc: 0.905536
# [14000]	training's auc: 0.943149	valid_1's auc: 0.905563
# [15000]	training's auc: 0.9452	valid_1's auc: 0.905563
# [16000]	training's auc: 0.9472	valid_1's auc: 0.905591
# [17000]	training's auc: 0.949108	valid_1's auc: 0.905545
# [18000]	training's auc: 0.950993	valid_1's auc: 0.90561
# [19000]	training's auc: 0.95282	valid_1's auc: 0.90563
# [20000]	training's auc: 0.954565	valid_1's auc: 0.905627
# [21000]	training's auc: 0.956352	valid_1's auc: 0.905663
# [22000]	training's auc: 0.958044	valid_1's auc: 0.90561
# [23000]	training's auc: 0.959668	valid_1's auc: 0.905598
# [24000]	training's auc: 0.96123	valid_1's auc: 0.905554
# [25000]	training's auc: 0.962754	valid_1's auc: 0.905508
# Early stopping, best iteration is:
# [20762]	training's auc: 0.955942	valid_1's auc: 0.905688
#
# Fold 5 - N 1
# Shape of X_train after augment: (336078, 400)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896648	valid_1's auc: 0.886559
# [2000]	training's auc: 0.905213	valid_1's auc: 0.89329
# [3000]	training's auc: 0.911522	valid_1's auc: 0.897398
# [4000]	training's auc: 0.916519	valid_1's auc: 0.900762
# [5000]	training's auc: 0.920526	valid_1's auc: 0.903008
# [6000]	training's auc: 0.923843	valid_1's auc: 0.904427
# [7000]	training's auc: 0.92672	valid_1's auc: 0.905382
# [8000]	training's auc: 0.929432	valid_1's auc: 0.906028
# [9000]	training's auc: 0.931869	valid_1's auc: 0.906451
# [10000]	training's auc: 0.934289	valid_1's auc: 0.906929
# [11000]	training's auc: 0.936576	valid_1's auc: 0.907115
# [12000]	training's auc: 0.938772	valid_1's auc: 0.907224
# [13000]	training's auc: 0.940932	valid_1's auc: 0.90731
# [14000]	training's auc: 0.943022	valid_1's auc: 0.9073
# [15000]	training's auc: 0.945073	valid_1's auc: 0.907464
# [16000]	training's auc: 0.947032	valid_1's auc: 0.907517
# [17000]	training's auc: 0.948978	valid_1's auc: 0.907563
# [18000]	training's auc: 0.950856	valid_1's auc: 0.907599
# [19000]	training's auc: 0.952693	valid_1's auc: 0.907679
# [20000]	training's auc: 0.954481	valid_1's auc: 0.907728
# [21000]	training's auc: 0.956232	valid_1's auc: 0.907761
# [22000]	training's auc: 0.957888	valid_1's auc: 0.907719
# [23000]	training's auc: 0.959494	valid_1's auc: 0.907727
# [24000]	training's auc: 0.961062	valid_1's auc: 0.907678
# [25000]	training's auc: 0.962614	valid_1's auc: 0.907662
# Early stopping, best iteration is:
# [20762]	training's auc: 0.955812	valid_1's auc: 0.907788

# %%
predictions['target'] = np.mean(predictions[[col for col in predictions.columns if col not in ['ID_code', 'target']]].values, axis=1)
predictions.to_csv('predictions.csv', index=None)
sub_df = pd.DataFrame({"ID_code":df_test["ID_code"].values})
sub_df["target"] = predictions['target']

# %%
sub_df.to_csv("/content/drive/MyDrive/Data Science Project - Team D/submission/submission_lgbm_fe1_binary.csv", index=False)

# %% [markdown]
# ## FE2

# %%
## Importing data

df_train = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/data/fe2-binary/train_fe2_binary.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/data/fe2-binary/test_fe2_binary.csv")

# %%
## Oversampling 

def oversampling(x, y, t=2):
    
    xs, xn = [], []
    
    for i in range(t // 2):
        mask = y == 0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        featnum = x1.shape[1] // 200 - 1

        for c in range(200):
            np.random.shuffle(ids)
            x1[:, [c] + [200 + featnum * c + idc for idc in range(featnum)]] = x1[ids][:, [c] + [200 + featnum * c + idc for idc in range(featnum)]]
        xn.append(x1)
    
    for i in range(t):
        mask = y > 0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        featnum = x1.shape[1] // 200 - 1
        
        for c in range(200):
            np.random.shuffle(ids)
            x1[:, [c] + [200 + featnum * c + idc for idc in range(1)]] = x1[ids][:, [c] + [200 + featnum * c + idc for idc in range(1)]]
        xs.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x, xs, xn])
    y = np.concatenate([y, ys, yn])
    
    return x, y

# %%
gbdt_param1 = {
    # Core Parameters
    'objective': 'binary',
    'boosting': 'gbdt',
    'learning_rate': 0.01,
    'num_leaves': 15,
    'tree_learner': 'serial',
    'num_threads': 8,
    'seed': SEED,
    
    # Learning Control Parameters
    'max_depth': -1,
    'min_data_in_leaf': 50,
    'min_sum_hessian_in_leaf': 10,  
    'bagging_fraction': 0.6,
    'bagging_freq': 5,
    'feature_fraction': 0.05,
    'lambda_l1': 1.,
    'bagging_seed': SEED,
    
    # Others
    'verbosity ': 1,
    'boost_from_average': False,
    'metric': 'auc',
}

# %%
predictors = df_train.columns.tolist()[2:]
X_test = df_test[predictors]

n_splits = 5
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

predictions = df_test[['ID_code']]

# %%
for fold, (train_ind, val_ind) in enumerate(skf.split(df_train, df_train.target.values)):
    
    X_train, y_train = df_train.iloc[train_ind][predictors], df_train.iloc[train_ind]['target']
    X_valid, y_valid = df_train.iloc[val_ind][predictors], df_train.iloc[val_ind]['target']

    N = 1
    p_valid, yp = 0, 0
        
    for i in range(N):
        print('\nFold {} - N {}'.format(fold + 1, i + 1))
        
        X_t, y_t = oversampling(X_train.values, y_train.values)
        weights = np.array([0.8] * X_t.shape[0])
        weights[:X_train.shape[0]] = 1.0
        print('Shape of X_train after augment: {}\nShape of y_train after augment: {}'.format(X_t.shape, y_t.shape))
        
        X_t = pd.DataFrame(X_t)
        X_t = X_t.add_prefix('var_')
    
        trn_data = lgb.Dataset(X_t, label=y_t, weight=weights)
        val_data = lgb.Dataset(X_valid, label=y_valid)
        evals_result = {}
        
        lgb_clf = lgb.train(gbdt_param1, trn_data, 100000, valid_sets=[trn_data, val_data], early_stopping_rounds=5000, verbose_eval=1000, evals_result=evals_result)
        p_valid += lgb_clf.predict(X_valid)
        yp += lgb_clf.predict(X_test)
        

    predictions['fold{}'.format(fold + 1)] = yp / N
# Out:
# Fold 1 - N 1
# Shape of X_train after augment: (336079, 370)
# Shape of y_train after augment: (336079,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.895453	valid_1's auc: 0.884311
# [2000]	training's auc: 0.904389	valid_1's auc: 0.891668
# [3000]	training's auc: 0.910631	valid_1's auc: 0.895877
# [4000]	training's auc: 0.915598	valid_1's auc: 0.898776
# [5000]	training's auc: 0.919384	valid_1's auc: 0.900838
# [6000]	training's auc: 0.922624	valid_1's auc: 0.902083
# [7000]	training's auc: 0.925388	valid_1's auc: 0.902777
# [8000]	training's auc: 0.927938	valid_1's auc: 0.903186
# [9000]	training's auc: 0.930337	valid_1's auc: 0.903452
# [10000]	training's auc: 0.932623	valid_1's auc: 0.90357
# [11000]	training's auc: 0.93486	valid_1's auc: 0.903602
# [12000]	training's auc: 0.93703	valid_1's auc: 0.903559
# [13000]	training's auc: 0.939158	valid_1's auc: 0.903502
# [14000]	training's auc: 0.941228	valid_1's auc: 0.903515
# [15000]	training's auc: 0.943225	valid_1's auc: 0.903544
# Early stopping, best iteration is:
# [10853]	training's auc: 0.934534	valid_1's auc: 0.903626
#
# Fold 2 - N 1
# Shape of X_train after augment: (336079, 370)
# Shape of y_train after augment: (336079,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.895066	valid_1's auc: 0.886092
# [2000]	training's auc: 0.904186	valid_1's auc: 0.893002
# [3000]	training's auc: 0.910252	valid_1's auc: 0.896916
# [4000]	training's auc: 0.915162	valid_1's auc: 0.899632
# [5000]	training's auc: 0.918945	valid_1's auc: 0.901278
# [6000]	training's auc: 0.922193	valid_1's auc: 0.902295
# [7000]	training's auc: 0.924935	valid_1's auc: 0.902787
# [8000]	training's auc: 0.927456	valid_1's auc: 0.903171
# [9000]	training's auc: 0.929888	valid_1's auc: 0.903368
# [10000]	training's auc: 0.932239	valid_1's auc: 0.903508
# [11000]	training's auc: 0.934491	valid_1's auc: 0.903524
# [12000]	training's auc: 0.936688	valid_1's auc: 0.9035
# [13000]	training's auc: 0.938827	valid_1's auc: 0.903401
# [14000]	training's auc: 0.940891	valid_1's auc: 0.903367
# [15000]	training's auc: 0.942906	valid_1's auc: 0.903269
# [16000]	training's auc: 0.944859	valid_1's auc: 0.90327
# Early stopping, best iteration is:
# [11576]	training's auc: 0.935774	valid_1's auc: 0.903582
#
# Fold 3 - N 1
# Shape of X_train after augment: (336078, 370)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896617	valid_1's auc: 0.878151
# [2000]	training's auc: 0.905339	valid_1's auc: 0.885121
# [3000]	training's auc: 0.911372	valid_1's auc: 0.88939
# [4000]	training's auc: 0.916215	valid_1's auc: 0.892558
# [5000]	training's auc: 0.919912	valid_1's auc: 0.894641
# [6000]	training's auc: 0.923067	valid_1's auc: 0.895996
# [7000]	training's auc: 0.925825	valid_1's auc: 0.897001
# [8000]	training's auc: 0.928358	valid_1's auc: 0.897672
# [9000]	training's auc: 0.930765	valid_1's auc: 0.898083
# [10000]	training's auc: 0.933073	valid_1's auc: 0.898298
# [11000]	training's auc: 0.935331	valid_1's auc: 0.89849
# [12000]	training's auc: 0.937485	valid_1's auc: 0.898579
# [13000]	training's auc: 0.939574	valid_1's auc: 0.898719
# [14000]	training's auc: 0.941635	valid_1's auc: 0.898679
# [15000]	training's auc: 0.943617	valid_1's auc: 0.898701
# [16000]	training's auc: 0.945565	valid_1's auc: 0.898639
# [17000]	training's auc: 0.947471	valid_1's auc: 0.898667
# [18000]	training's auc: 0.949353	valid_1's auc: 0.898587
# [19000]	training's auc: 0.951151	valid_1's auc: 0.898488
# Early stopping, best iteration is:
# [14357]	training's auc: 0.942344	valid_1's auc: 0.898728
#
# Fold 4 - N 1
# Shape of X_train after augment: (336078, 370)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.895778	valid_1's auc: 0.885185
# [2000]	training's auc: 0.904793	valid_1's auc: 0.892262
# [3000]	training's auc: 0.91093	valid_1's auc: 0.896311
# [4000]	training's auc: 0.915805	valid_1's auc: 0.899086
# [5000]	training's auc: 0.9196	valid_1's auc: 0.90095
# [6000]	training's auc: 0.922757	valid_1's auc: 0.902125
# [7000]	training's auc: 0.925522	valid_1's auc: 0.902938
# [8000]	training's auc: 0.928056	valid_1's auc: 0.903314
# [9000]	training's auc: 0.930453	valid_1's auc: 0.903494
# [10000]	training's auc: 0.932774	valid_1's auc: 0.903698
# [11000]	training's auc: 0.935033	valid_1's auc: 0.903732
# [12000]	training's auc: 0.937195	valid_1's auc: 0.903727
# [13000]	training's auc: 0.939311	valid_1's auc: 0.903722
# [14000]	training's auc: 0.941383	valid_1's auc: 0.903666
# [15000]	training's auc: 0.943407	valid_1's auc: 0.903624
# [16000]	training's auc: 0.945356	valid_1's auc: 0.903548
# Early stopping, best iteration is:
# [11421]	training's auc: 0.935954	valid_1's auc: 0.903782
#
# Fold 5 - N 1
# Shape of X_train after augment: (336078, 370)
# Shape of y_train after augment: (336078,)
# Training until validation scores don't improve for 5000 rounds.
# [1000]	training's auc: 0.896567	valid_1's auc: 0.885164
# [2000]	training's auc: 0.905315	valid_1's auc: 0.892742
# [3000]	training's auc: 0.911436	valid_1's auc: 0.897108
# [4000]	training's auc: 0.916353	valid_1's auc: 0.900152
# [5000]	training's auc: 0.920124	valid_1's auc: 0.901896
# [6000]	training's auc: 0.923331	valid_1's auc: 0.903096
# [7000]	training's auc: 0.926128	valid_1's auc: 0.903839
# [8000]	training's auc: 0.92862	valid_1's auc: 0.904307
# [9000]	training's auc: 0.93098	valid_1's auc: 0.904515
# [10000]	training's auc: 0.933311	valid_1's auc: 0.904619
# [11000]	training's auc: 0.935545	valid_1's auc: 0.904746
# [12000]	training's auc: 0.937694	valid_1's auc: 0.904763
# [13000]	training's auc: 0.939793	valid_1's auc: 0.904758
# [14000]	training's auc: 0.941819	valid_1's auc: 0.904712
# [15000]	training's auc: 0.943824	valid_1's auc: 0.904714
# [16000]	training's auc: 0.945798	valid_1's auc: 0.904615
# Early stopping, best iteration is:
# [11646]	training's auc: 0.936933	valid_1's auc: 0.90479

# %%
predictions['target'] = np.mean(predictions[[col for col in predictions.columns if col not in ['ID_code', 'target']]].values, axis=1)
predictions.to_csv('predictions.csv', index=None)
sub_df = pd.DataFrame({"ID_code":df_test["ID_code"].values})
sub_df["target"] = predictions['target']

# %%
sub_df.to_csv("/content/drive/MyDrive/Data Science Project - Team D/submission/various-submissions/submission_lgbm_fe2_binary.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5f2e85e7bfd> in <module>
# ----> 1 sub_df.to_csv("/content/drive/MyDrive/Data Science Project - Team D/submission/various-submissions/submission_lgbm_fe2_binary.csv", index=False)
#
# NameError: name 'sub_df' is not defined
